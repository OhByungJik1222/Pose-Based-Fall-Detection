# %%
# !unzip "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상(1280x720,10fps).zip" -d "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: /content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Validation/02.라벨링데이터/VL/이미지/N/N/00653_H_D_N_C2/00653_H_D_N_C2_I008.json
#   inflating: /content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Validation/02.라벨링데이터/VL/이미지/N/N/00653_H_D_N_C2/00653_H_D_N_C2_I009.json
#   inflating: /content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Validation/02.라벨링데이터/VL/이미지/N/N/00653_H_D_N_C2/00653_H_D_N_C2_I010.json
#    creating: /content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Validation/02.라벨링데이터/VL/이미지/N/N/00653_H_D_N_C3/
# ...

# %%
# !du -sh "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상"
# Out:
# 76G	/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상

# %%
# !cd "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터"

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data_resized/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Training/01.원천데이터/TS/센서/N/N"  \
  -type f -name "*_H_*" | wc -l
# Out:
# 0

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data_resized/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Training/01.원천데이터/TS/센서/Y/SY" \
  -type f -name "*_H_*" | wc -l
# Out:
# 0

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data_resized/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Training/01.원천데이터/TS/영상/N/N" \
  -type f -name "*_H_*" | wc -l
# Out:
# 0

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data_resized/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Training/01.원천데이터/TS/영상/Y/SY" \
  -type f -name "*_H_*" | wc -l
# Out:
# 0

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data_resized/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Training/01.원천데이터/TS/이미지/N/N" \
  -type f -name "*_H_*" | wc -l
# Out:
# 22720

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data_resized/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Training/01.원천데이터/TS/이미지/Y/SY" \
  -type f -name "*_H_*" | wc -l
# Out:
# 18560

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data_resized/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Training/02.라벨링데이터/TL/센서/N/N" -type f | wc -l
# Out:
# 2272

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data_resized/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Training/02.라벨링데이터/TL/센서/Y/SY" \
  -type f -name "*_H_*" | wc -l
# Out:
# 1856

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data_resized/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Training/02.라벨링데이터/TL/영상/N/N" \
  -type f -name "*_H_*" | wc -l
# Out:
# 2272

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data_resized/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Training/02.라벨링데이터/TL/영상/Y/SY" -type f | wc -l
# Out:
# 1856

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data_resized/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Training/02.라벨링데이터/TL/이미지/N/N" \
  -type f -name "*_H_*" | wc -l
# Out:
# 22720

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data_resized/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Training/02.라벨링데이터/TL/이미지/Y/SY" \
  -type f -name "*_H_*" | wc -l
# Out:
# 18560

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data_resized/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Validation/01.원천데이터/VS/센서/N/N" \
  -type f -name "*_H_*" | wc -l
# Out:
# 0

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data_resized/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Validation/01.원천데이터/VS/센서/Y/SY" \
  -type f -name "*_H_*" | wc -l
# Out:
# 0

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data_resized/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Validation/01.원천데이터/VS/영상/N/N" \
  -type f -name "*_H_*" | wc -l
# Out:
# 0

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data_resized/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Validation/01.원천데이터/VS/영상/Y/SY" \
  -type f -name "*_H_*" | wc -l
# Out:
# 0

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data_resized/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Validation/01.원천데이터/VS/이미지/N" \
  -type f -name "*_H_*" | wc -l
# Out:
# 3120

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data_resized/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Validation/01.원천데이터/VS/이미지/Y" \
  -type f -name "*_H_*" | wc -l
# Out:
# 2800

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data_resized/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Validation/02.라벨링데이터/VL/센서/N" \
  -type f -name "*_H_*" | wc -l
# Out:
# 312

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data_resized/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Validation/02.라벨링데이터/VL/센서/Y" -type f | wc -l
# Out:
# 280

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data_resized/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Validation/02.라벨링데이터/VL/영상/N" \
  -type f -name "*_H_*" | wc -l
# Out:
# 312

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data_resized/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Validation/02.라벨링데이터/VL/영상/Y" \
  -type f -name "*_H_*" | wc -l
# Out:
# 280

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data_resized/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Validation/02.라벨링데이터/VL/이미지/N" \
  -type f -name "*_H_*" | wc -l
# Out:
# 3120

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data_resized/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Validation/02.라벨링데이터/VL/이미지/Y" \
  -type f -name "*_H_*" | wc -l
# Out:
# 2800

# %%
# !apt-get install tree -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 41 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 0s (102 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 121713 files and directories currently installed.)
# Preparing to unpack .../tree_2.0.2-1_amd64.deb ...
# Unpacking tree (2.0.2-1) ...
# Setting up tree (2.0.2-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !tree "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Training/02.라벨링데이터/TL/센서/N/N" -L 3
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# ├── 01144_O_E_N_C6
# │   └── 01144_O_E_N_C6.json
# ├── 01144_O_E_N_C7
# │   └── 01144_O_E_N_C7.json
# ├── 01144_O_E_N_C8
# │   └── 01144_O_E_N_C8.json
# ├── 01147_O_E_N_C1
# │   └── 01147_O_E_N_C1.json
# ├── 01147_O_E_N_C2
# │   └── 01147_O_E_N_C2.json
# ├── 01147_O_E_N_C3
# │   └── 01147_O_E_N_C3.json
# ├── 01147_O_E_N_C4
# │   └── 01147_O_E_N_C4.json
# ├── 01147_O_E_N_C5
# │   └── 01147_O_E_N_C5.json
# ├── 01147_O_E_N_C6
# │   └── 01147_O_E_N_C6.json
# ├── 01147_O_E_N_C7
# │   └── 01147_O_E_N_C7.json
# ├── 01147_O_E_N_C8
# │   └── 01147_O_E_N_C8.json
# ├── 01148_O_E_N_C1
# │   └── 01148_O_E_N_C1.json
# ├── 01148_O_E_N_C2
# │   └── 01148_O_E_N_C2.json
# ├── 01148_O_E_N_C3
# │   └── 01148_O_E_N_C3.json
# ├── 01148_O_E_N_C4
# │   └── 01148_O_E_N_C4.json
# ├── 01148_O_E_N_C5
# │   └── 01148_O_E_N_C5.json
# ├── 01148_O_E_N_C6
# │   └── 01148_O_E_N_C6.json
# ├── 01148_O_E_N_C7
# │   └── 01148_O_E_N_C7.json
# ├── 01148_O_E_N_C8
# ...

# %%
TARGET="/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Training/02.라벨링데이터/TL/센서/N/N"

# %%
# !find "/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Training/02.라벨링데이터/TL/센서/N/N" -type f | wc -l
# Out:
# 4544

# %%
TARGET="/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Training/02.라벨링데이터/TL/센서/N/N"

# %%
# !find "$TARGET" -mindepth 1 -type d | wc -l
# Out:
# 4544

# %%
# !find "$TARGET" -type d -name "*_H_*" | wc -l
# Out:
# 2272

# %%
# !find "$TARGET" -type d -name "*_O_*" | wc -l
# Out:
# 1608

# %%
# !find "$TARGET" -type d -name "*_Y_*" | wc -l
# Out:
# 656

# %%
# !find "$TARGET" -type d -name "*_L_*" | wc -l
# Out:
# 8

# %%
# !find "$TARGET" -type d \( -name "*_O_*" -o -name "*_Y_*" -o -name "*_L_*" \) | wc -l
# Out:
# 2272

# %%
# !find "$TARGET" -type d \( -name "*_O_*" -o -name "*_Y_*" -o -name "*_L_*" \) -print0 | xargs -0 rm -rf

# %%
# !find "$TARGET" -mindepth 1 -type d | wc -l
# Out:
# 2272

# %%
# !find "$TARGET" -type d -name "*_H_*" | wc -l
# Out:
# 2272

# %%
TARGET="/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Training/02.라벨링데이터/TL/영상/Y/SY"

# %%
# !find "$TARGET" -mindepth 1 -type d | wc -l
# Out:
# 1857

# %%
# !find "$TARGET" -type d -name "*_H_*" | wc -l
# Out:
# 1856

# %%
# !find "$TARGET" -type d -name "*_O_*" | wc -l
# Out:
# 0

# %%
# !find "$TARGET" -type d -name "*_Y_*" | wc -l
# Out:
# 0

# %%
# !find "$TARGET" -type d -name "*_L_*" | wc -l
# Out:
# 1

# %%
# !find "$TARGET" -type d \( -name "*_O_*" -o -name "*_Y_*" -o -name "*_L_*" \) | wc -l
# Out:
# 1

# %%
# !find "$TARGET" -type d \( -name "*_O_*" -o -name "*_Y_*" -o -name "*_L_*" \) -print0 | xargs -0 rm -rf

# %%
# !find "$TARGET" -mindepth 1 -type d | wc -l
# Out:
# 1856

# %%
# !find "$TARGET" -type d -name "*_H_*" | wc -l
# Out:
# 1856

# %%
TARGET="/content/drive/MyDrive/[Projects]/AI Hub/Pose Detection 기반 실시간 낙상 감지 시스템 개발/Data/data/낙상사고 위험동작 영상-센서 쌍 데이터_병원,후면낙상/3.개방데이터/1.데이터/Validation/02.라벨링데이터/VL/센서/Y/SY"

# %%
# !find "$TARGET" -mindepth 1 -type d | wc -l
# Out:
# 352

# %%
# !find "$TARGET" -type d -name "*_H_*" | wc -l
# Out:
# 280

# %%
# !find "$TARGET" -type d -name "*_O_*" | wc -l
# Out:
# 32

# %%
# !find "$TARGET" -type d -name "*_Y_*" | wc -l
# Out:
# 40

# %%
# !find "$TARGET" -type d -name "*_L_*" | wc -l
# Out:
# 0

# %%
# !find "$TARGET" -mindepth 1 -type d \
  ! -name "*_H_*" \
  ! -name "*_O_*" \
  ! -name "*_L_*" \
  ! -name "*_Y_*"

# %%
# !find "$TARGET" -type d \( -name "*_O_*" -o -name "*_Y_*" -o -name "*_L_*" \) | wc -l
# Out:
# 72

# %%
# !find "$TARGET" -type d \( -name "*_O_*" -o -name "*_Y_*" -o -name "*_L_*" \) -print0 | xargs -0 rm -rf

# %%
# !find "$TARGET" -mindepth 1 -type d | wc -l
# Out:
# 280

# %%
# !find "$TARGET" -type d -name "*_H_*" | wc -l
# Out:
# 280
